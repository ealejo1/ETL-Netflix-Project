# %% [markdown]
# ## Imports and Modules.

# %%
import pandas as pd

# %% [markdown]
# ## Read csvs.

# %%
shows_df = pd.read_csv("netflix_shows.csv", sep=",", encoding='latin-1')
shows_df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                           rating_level  rating_description  \
# 0    crude and sexual humor, language and some drug...                  80
# 1    strong violence, sexual content and adult lang...                 100
# 2    Parents strongly cautioned. May be unsuitable ...                  90
# 3    Parents strongly cautioned. May be unsuitable ...                  90
# 4    Parental guidance suggested. May not be suitab...                  70
# ...

# %%
# Remove unnecessary data from netflix_shows.csv (NaN values)
shows_df.dropna(inplace=True)
shows_df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# 5               Supernatural  TV-14
# ..                       ...    ...
# 984     The Magic School Bus   TV-Y
# 986  PokÌ©mon: Indigo League   TV-Y
# 988               Paddington     PG
# 991       Dawn of the Croods  TV-Y7
# 995                  The BFG     PG
#
#                                           rating_level  rating_description  \
# 0    crude and sexual humor, language and some drug...                  80
# 2    Parents strongly cautioned. May be unsuitable ...                  90
# 3    Parents strongly cautioned. May be unsuitable ...                  90
# 4    Parental guidance suggested. May not be suitab...                  70
# 5    Parents strongly cautioned. May be unsuitable ...                  90
# ...

# %%
# Read csv for shows. 
titles_df = pd.read_csv("netflix_titles.csv")
titles_df
# Out:
#        show_id show_type                                        title  \
# 0     81145628     Movie      Norm of the North: King Sized Adventure
# 1     80117401     Movie                   Jandino: Whatever it Takes
# 2     70234439   TV Show                           Transformers Prime
# 3     80058654   TV Show             Transformers: Robots in Disguise
# 4     80125979     Movie                                 #realityhigh
# ...        ...       ...                                          ...
# 6229  80000063   TV Show                                 Red vs. Blue
# 6230  70286564   TV Show                                        Maron
# 6231  80116008     Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022   TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404   TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# ...

# %%
titles_df.dropna(inplace=True)
titles_df
# Out:
#        show_id show_type                                    title  \
# 0     81145628     Movie  Norm of the North: King Sized Adventure
# 4     80125979     Movie                             #realityhigh
# 6     70304989     Movie                                 Automata
# 7     80164077     Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990     Movie                              Good People
# ...        ...       ...                                      ...
# 6142  80063224   TV Show            The Great British Baking Show
# 6158  80164216   TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 6167  80115328   TV Show                             Sacred Games
# 6182  80176842   TV Show                         Men on a Mission
# 6213  80126599   TV Show                         Leyla and Mecnun
#
#                                   director  \
# 0                 Richard Finn, Tim Maltby
# 4                         Fernando Lebrija
# ...

# %%
#Extract Movies and TV Shows from the Philippines on Netflix. 
titles_df[titles_df["show_type"]=="Movie"]
titles_df[titles_df["country"]=="Philippines"]
# Out:
#        show_id show_type                          title  \
# 469   80084834     Movie                   Heneral Luna
# 1316  80222787     Movie                        BuyBust
# 1718  80236341     Movie                          Maria
# 1957  81010867     Movie                     Sisterakas
# 1958  81010865     Movie            Starting Over Again
# 1959  81010874     Movie      That Thing Called Tadhana
# 1960  80075018     Movie                The Love Affair
# 1979  70110919     Movie                      Caregiver
# 1983  80085013     Movie            Everyday I Love You
# 1985  80049193     Movie                     Kid Kulafu
# 1987  81010871     Movie                 No Other Woman
# 2101  81010863     Movie  The Amazing Praybeyt Benjamin
# 2102  80162503     Movie   The Super Parental Guardians
# 2103  80150350     Movie                The Third Party
# 2104  80160692     Movie             The Unmarried Wife
# 2105  70060865     Movie              The Wedding Curse
# ...

# %% [markdown]
# ## Load Data into Database through SQLAlchemy.

# %%
import credentials

# %%
from sqlalchemy import create_engine
engine = create_engine(f"postgres://postgres:{credentials.pgadmin_pw}@localhost:5432/Netflix_Shows_DB")

# %%
# Shows DataFrame to SQL persistence. 
shows_df.to_sql("shows",con=engine,if_exists="append",index=False)

# %%
# Titles DataFrame to SQL persistence
titles_df.to_sql("titles", con=engine, if_exists="append",index=False)
